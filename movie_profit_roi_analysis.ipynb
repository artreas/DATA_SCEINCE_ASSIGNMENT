# %% [markdown]
# <a href="https://colab.research.google.com/github/artreas/DATA_SCEINCE_ASSIGNMENT/blob/main/movie_profit_roi_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **IMPORTING FILES**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cd63ade4-8cb1-46a7-88c4-51de3eda0d98" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd63ade4-8cb1-46a7-88c4-51de3eda0d98">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("imdb_data (1).csv")
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %% [markdown]
# **Data Exploration & Sanity**

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %% [markdown]
# **Handle missing values**

# %%
genres = set()

for g in df['genres'].dropna():
    genres.update(g.split('|'))

list(genres)
# Out:
# ["[{'id': 28, 'name': 'Action'}, {'id': 27, 'name': 'Horror'}, {'id': 878, 'name': 'Science Fiction'}]",
#  "[{'id': 28, 'name': 'Action'}, {'id': 35, 'name': 'Comedy'}, {'id': 9648, 'name': 'Mystery'}, {'id': 53, 'name': 'Thriller'}]",
#  "[{'id': 27, 'name': 'Horror'}, {'id': 28, 'name': 'Action'}, {'id': 878, 'name': 'Science Fiction'}]",
#  "[{'id': 18, 'name': 'Drama'}, {'id': 14, 'name': 'Fantasy'}, {'id': 878, 'name': 'Science Fiction'}]",
#  "[{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 878, 'name': 'Science Fiction'}]",
#  "[{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}, {'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}]",
#  "[{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}, {'id': 10769, 'name': 'Foreign'}]",
#  "[{'id': 18, 'name': 'Drama'}, {'id': 9648, 'name': 'Mystery'}, {'id': 53, 'name': 'Thriller'}, {'id': 80, 'name': 'Crime'}]",
# ...

# %% [markdown]
# **Convert columns if needed**

# %%
df.columns
df['budget'] = pd.to_numeric(df['budget'], errors='coerce')
df['revenue'] = pd.to_numeric(df['revenue'], errors='coerce')

# %% [markdown]
# **Create Profit & ROI**

# %%
df['profit'] = df['revenue'] - df['budget']
df['roi'] = df['profit'] / df['budget']

# %% [markdown]
# **Highest Profit Movie**

# %%
max_profit_movie = df.loc[df['profit'].idxmax()]

max_profit_movie[['title', 'profit']]
# Out:
# title      Furious 7
# profit    1316249360
# Name: 1761, dtype: object

# %% [markdown]
# **Language with Highest Avg ROI**

# %%
lang_roi = df.groupby('original_language')['roi'].mean().sort_values(ascending=False)
lang_roi.head()
# Out:
# original_language
# ar    inf
# bn    inf
# cn    inf
# cs    inf
# da    inf
# Name: roi, dtype: float64

# %% [markdown]
# **Unique Genres**

# %%
import ast

genres = set()

for g in df['genres'].dropna():
    genre_list = ast.literal_eval(g)
    for item in genre_list:
        genres.add(item['name'])

list(genres)
# Out:
# ['Fantasy',
#  'Horror',
#  'Romance',
#  'Foreign',
#  'History',
#  'TV Movie',
#  'Comedy',
#  'Music',
#  'Family',
#  'Thriller',
#  'Drama',
#  'Western',
#  'Animation',
#  'Adventure',
#  'Science Fiction',
#  'Mystery',
#  'Documentary',
#  'Action',
#  'Crime',
#  'War']

# %% [markdown]
# **Top 3 Producers by Avg ROI**

# %%
# Convert to numeric
df['budget'] = pd.to_numeric(df['budget'], errors='coerce')
df['revenue'] = pd.to_numeric(df['revenue'], errors='coerce')

# Remove invalid values
df = df.dropna(subset=['budget', 'revenue'])
df = df[df['budget'] > 0]

# Create profit & ROI
df['profit'] = df['revenue'] - df['budget']
df['roi'] = df['profit'] / df['budget']

# Remove infinite ROI
df = df.replace([np.inf, -np.inf], np.nan)
df = df.dropna(subset=['roi'])

# Extract producers
def get_producers(x):
    try:
        companies = ast.literal_eval(x)
        return [c['name'] for c in companies]
    except:
        return []

df['producers'] = df['production_companies'].apply(get_producers)

# Explode producers
df_exploded = df.explode('producers')

# Compute top 3 producers by avg ROI
producer_roi = df_exploded.groupby('producers')['roi'].mean().sort_values(ascending=False)

producer_roi.head(3)
# Out:
# producers
# Charles Chaplin Productions    4.250004e+06
# Film It Suda                   4.197476e+06
# Delphi V Productions           1.018618e+06
# Name: roi, dtype: float64

# %% [markdown]
# **Actor with Most Movies**

# %%
def get_actors(cast):
    try:
        cast_list = ast.literal_eval(cast)
        return [actor['name'] for actor in cast_list]
    except:
        return []

df['actors'] = df['cast'].apply(get_actors)

df_actors = df.explode('actors')

top_actor = df_actors['actors'].value_counts().idxmax()
top_actor
# Out:
# 'Samuel L. Jackson'

# %%
import ast

# Clean genres function
def clean_genres(g):
    try:
        genre_list = ast.literal_eval(g)
        return ", ".join([item['name'] for item in genre_list])
    except:
        return ""

# Apply cleaning
actor_movies['genres'] = actor_movies['genres'].apply(clean_genres)

# Reset index
actor_movies = actor_movies.reset_index(drop=True)

# Final clean output
actor_movies[['title', 'genres', 'profit', 'roi']].head()
# Out:
# /tmp/ipykernel_13427/3609533034.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   actor_movies['genres'] = actor_movies['genres'].apply(clean_genres)
#                                           title  \
# 0                                Changing Lanes
# 1                             The Hateful Eight
# 2                             Coming to America
# 3  Star Wars: Episode III - Revenge of the Sith
# 4                                  The Avengers
#
#                                genres      profit       roi
# 0  Action, Adventure, Crime, Thriller    49935764  1.109684
# 1      Crime, Drama, Mystery, Western   111760117  2.540003
# 2                     Comedy, Romance   249752301  6.403905
# ...

# %% [markdown]
# **Top 3 Directors & Their Favorite Actors**

# %%
import ast
import pandas as pd

# Extract director
def get_director(crew):
    try:
        crew_list = ast.literal_eval(crew)
        for person in crew_list:
            if person['job'] == 'Director':
                return person['name']
    except:
        return None

df['director'] = df['crew'].apply(get_director)

# Extract actors
def get_actors(cast):
    try:
        cast_list = ast.literal_eval(cast)
        return [actor['name'] for actor in cast_list]
    except:
        return []

df['actors'] = df['cast'].apply(get_actors)

# Top 3 directors
top_directors = df['director'].value_counts().head(3).index

# Create clean result list
results = []

for director in top_directors:
    sub = df[df['director'] == director]

    actors = sub['actors'].explode()
    top_actors = actors.value_counts().head(3)

    for actor, count in top_actors.items():
        results.append([director, actor, count])

# Convert to DataFrame
result_df = pd.DataFrame(results, columns=['Director', 'Actor', 'Movie_Count'])

result_df
# Out:
#             Director            Actor  Movie_Count
# 0   Steven Spielberg    Harrison Ford            3
# 1   Steven Spielberg        Pat Roach            2
# 2   Steven Spielberg        Tom Hanks            2
# 3     Clint Eastwood   Clint Eastwood            6
# 4     Clint Eastwood  Annie O'Donnell            2
# 5     Clint Eastwood     Laura Linney            2
# 6  Steven Soderbergh   George Clooney            3
# 7  Steven Soderbergh      Viola Davis            3
# 8  Steven Soderbergh     Luis Guzmán            3
